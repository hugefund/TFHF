# %%
import pandas as pd

# %%
from pyecharts import options as opts
from pyecharts.charts import Page, WordCloud
from pyecharts.globals import SymbolType

# %%
filedir = '/Users/Lee/Desktop/hui/stopwords-master/'

# %%
#coding:utf-8
 
readDir = "./stopwords.txt"
writeDir = "./stopwordsGeneral.txt"
outfile=open(writeDir,"w")
f = open(readDir,"r")
 
lines_seen = set()  # Build an unordered collection of unique elements.
 
for line in f:
    line = line.strip('\n')
    if line not in lines_seen:
        outfile.write(line+ '\n')
        lines_seen.add(line)

# %%
filenames=os.listdir(filedir)
filenames
# Out:
# ['baidu_stopwords.txt',
#  'scu_stopwords.txt',
#  'cn_stopwords.txt',
#  'hit_stopwords.txt']

# %%
f=open('stopwords.txt','w')
#先遍历文件名
for filename in filenames:
    filepath = filedir+'/'+filename
    #遍历单个文件，读取行数
    for line in open(filepath):
        f.writelines(line)
    f.write('\n')
#关闭文件
f.close()

# %%
with open('stop_words.txt','w') as f:

# %%
open('/Users/Lee/Desktop/hui/stopwords-master/baidu_stopwords.txt')

# %%
jieba.analyse.set_stop_words('/Users/Lee/Desktop/hui/stopwords-master/baidu_stopwords.txt')

# %%
# 三种方式：1，看投资者提问的时间分布；2，看回答的时间分布；3，看时间差以及分布；4，看来源；5、看提问的内容

# %%
def clearSen(comment):
    comment = comment.strip()
    comment = comment.replace('、', '')
    comment = comment.replace('，', '。')
    comment = comment.replace('《', '。')
    comment = comment.replace('》', '。')
    comment = comment.replace('～', '')
    comment = comment.replace('…', '')
    comment = comment.replace('\r', '')
    comment = comment.replace('\t', ' ')
    comment = comment.replace('\f', ' ')
    comment = comment.replace('/', '')
    comment = comment.replace('、', ' ')
    comment = comment.replace('/', '')
    comment = comment.replace('。', '')
    comment = comment.replace('（', '')
    comment = comment.replace('）', '')
    comment = comment.replace('_', '')
    comment = comment.replace('?', ' ')
    comment = comment.replace('？', ' ')
    comment = comment.replace('了', '')
    comment = comment.replace('➕', '')
    comment = comment.replace('：', '')
    return comment

# %%
outputfile = open('2016_jieba_output.txt', 'a+')

# %%
for each in ''.join(question):
    # 清除标点符号
    kk = clearSen(each)
    # 精确模式切词
    seg_list = jieba.cut(kk)
    comment = " ".join(seg_list)
    print(comment)
    # 写出数据
    outputfile.write(comment)
# 关闭文件
outputfile.close()

# %%
from IPython.display import Latex

# %%
outfile

# %%
ret_content = pd.read_table('./2016_jieba_output.txt', sep='\t')

# %%
with open('./2016_jieba_output.txt','r') as file:
    content = ''.join(file.readlines())

# %%
seg_list = content.split(' ')

# %%
seg_list
# Out:
# ['请问董秘公司受本次全国性限电影响多大',
#  '如何应对',
#  '你们基本面出啥问题么',
#  '怎么股价一直跌',
#  '还是因为芯片供应出大问题',
#  '请问贵公司对激光微投是否有产品布局',
#  '如没有是出于何种考量',
#  '贵公司投影仪能通过vr眼镜观看3d效果电影或者玩3d游戏么',
#  '公司最新股东人数1亚马逊封号公司是否受到影响2有传言公司在美国被一家小公司起诉专利侵权是否有重大影响',
#  '员工现在工作时长是如何的',
#  '看招聘上写的双休实际上每个月第一个周六是需要全员上班的并且公司加班情况十分严重基本都是晚上9-12点下班只有10-20的餐补请问这段时间员工的回家安全以及身体心理健康是否有保证',
#  '公司上市的招股书显示研发费用不足5%请问法定的社保是否足额缴纳',
#  '加班薪资是否如实发放',
#  '请问贵司微投产品有无采用鸿蒙操作系统的计划',
#  '如有具体是什么',
#  '另外和华为智能终端合作具体表现形式是什么',
#  '线下补课有被限制的趋势后期应该都会转到线上补课线上补课的话手机IPAD电脑屏幕都太小对视力危害非常大公司的产品是最适合孩子观看的是否有加大在线教育的资源投入现在华为芯片被美帝禁止而公司与华为的关系好像不错能不能把他们的微投芯片团队挖过来实现双赢公司产品出海进展如何',
#  '现在海外疫情严重急需公司产品以免老外整日到处瞎逛扩大疫情希望公司早日出海成功为抗疫做点贡献啊公司微投产品国内历年累计出货量最新有多少',
#  '客户使用频率如何',
#  '请问贵司自研光机的核心零部件是自产还是外购若外购供应稳定性如何',
#  '公司在这方面有何应对措施',
#  '公司在酒店电视替代方面有无计划',
#  '内容上是否有更多动作',
#  '作为股东且客户内容匮乏和付费观看十分影响使用频率不知公司有无关注该问题',
#  '贵公司产品的系统是否已经使用鸿蒙系统如果没有是否准备使用鸿蒙系统',
#  '尊敬的董秘您好！今年618贵公司产品在电商平台的销量是不是超过去年同期',
# ...

# %%
ret_content.columns=['content']

# %%
seg_list=jieba.cut(content)
list(seg_list)

# %%
seg = Taskflow("word_segmentation")

# %%
seg_list = seg(content)

# %%
# stopwords为停用词list
stopwords = [line.strip() for line in open('/Users/Lee/Desktop/hui/stopwords-master/baidu_stopwords.txt', 'r').readlines()]

# %%
stopwords2 = [line.strip() for line in open('/Users/Lee/Desktop/hui/stopwords-master/cn_stopwords.txt', 'r').readlines()]

# %%
stopwords3 = [line.strip() for line in open('/Users/Lee/Desktop/hui/stopwords-master/hit_stopwords.txt', 'r').readlines()]

# %%
stopwords4 = [line.strip() for line in open('/Users/Lee/Desktop/hui/stopwords-master/scu_stopwords.txt', 'r').readlines()]

# %%
stopwords = [line.strip() for line in open('./stopwords.txt', 'r').readlines()]

# %%
outstr = '' # 待返回字符串
for word in list(seg_list):
    if word not in stopwords:
        outstr += word + " "

# %%
import re

# %%
ret = re.sub('[公司,请问，董秘，贵，贵司]','',outstr)

# %%
outstr2 = '' # 待返回字符串
for word in list(outstr):
    if word not in stopwords2:
        outstr2 += word + " "

# %%
ret

# %%
from wordcloud import WordCloud
wordcloud = WordCloud().generate()

# %%
name=list(counter_ret.keys())
# name

# %%
value=list(counter_ret.values())

# %%
result = [(name,value) for name,value in counter_ret.items()]

# %%
wordcloud = WordCloud()

# %%
wordcloud.add("", result)
wordcloud.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="24c0e18f40c6420f9df5eab918c017c2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_24c0e18f40c6420f9df5eab918c017c2 = echarts.init(
#                     document.getElementById('24c0e18f40c6420f9df5eab918c017c2'), 'white', {renderer: 'canvas'});
#                 var option_24c0e18f40c6420f9df5eab918c017c2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
# ...

# %%
c = (
    WordCloud()
    .add("", counter_ret,word_size_range=[20, 100], shape=SymbolType.DIAMOND)
    .set_global_opts(title_opts=opts.TitleOpts(title="WordCloud-shape-diamond"))
    .render("wordcloud_diamond.html")
)

# %%
ret = ''.join(ret)

# %%
wordcloud = WordCloud().generate(ret)

# %%
dir(wordcloud)
# Out:
# ['__array__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_generated',
#  '_draw_contour',
#  '_get_bolean_mask',
#  'background_color',
#  'collocation_threshold',
#  'collocations',
#  'color_func',
#  'colormap',
#  'contour_color',
#  'contour_width',
#  'fit_words',
#  'font_path',
#  'font_step',
#  'generate',
#  'generate_from_frequencies',
#  'generate_from_text',
#  'height',
#  'include_numbers',
#  'layout_',
#  'margin',
#  'mask',
#  'max_font_size',
#  'max_words',
#  'min_font_size',
#  'min_word_length',
#  'mode',
#  'normalize_plurals',
#  'prefer_horizontal',
#  'process_text',
# ...

# %%
wordcloud.to_file(r"wordcloud.png")

# %%
plt.rcParams["font.sans-serif"]=["SimHei"]
#用来正常显示负号
plt.rcParams["axes.unicode_minus"]=False

# %%
plt.imshow(wordcloud)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
ret = ret.strip().split(' ')

# %%
ret = ret.split(' ')
ret
# Out:
# ['受',
#  '本次',
#  '全国性',
#  '限电',
#  '影响',
#  '多大',
#  '应对',
#  '面',
#  '出',
#  '股价',
#  '跌',
#  '芯片',
#  '供应',
#  '出',
#  '激光',
#  '微',
#  '投',
#  '产品',
#  '布局',
#  '如',
#  '没有',
#  '何种',
#  '考量',
#  '投影仪',
#  'vr眼镜',
#  '观看',
#  '3d',
#  '效果',
#  '电影',
#  '玩',
#  '3d游戏',
#  '最新',
#  '股东',
#  '人数',
#  '亚马逊',
#  '封号',
#  '影响',
#  '传言',
#  '美国',
#  '一家',
#  '起诉',
#  '专利',
#  '侵权',
#  '影响',
#  '员工',
#  '工作时',
#  '长',
#  '招聘',
#  '写',
#  '双休',
#  '实际上',
#  '每个月',
#  '第一个',
#  '周六',
#  '全员',
#  '上班',
#  '加班',
#  '情况',
#  '都是',
#  '晚上12点',
#  '下班',
#  '1020',
#  '餐',
#  '补',
#  '段',
#  '时间',
#  '员工',
#  '回家',
#  '身体',
#  '心理',
#  '健康',
#  '保证',
#  '上市',
#  '招股书',
#  '显示',
#  '研发',
#  '费用',
#  '5%',
#  '法定',
#  '社保',
#  '足额',
#  '缴纳',
#  '加班',
#  '薪资',
#  '如实',
#  '发放',
#  '微投',
#  '产品',
#  '有无',
#  '采用',
#  '鸿蒙',
#  '操作系统',
#  '计划',
#  '如有',
#  '华为',
#  '智能',
#  '终端',
#  '合作',
#  '表现形式',
#  '线',
#  '下',
#  '补课',
#  '趋势',
#  '后期',
#  '都会',
#  '转到',
#  '线上',
#  '补课',
#  '线上',
#  '补课',
# ...

# %%
counter_ret = Counter(ret)

# %%
counter_ret
# Out:
# Counter({'受': 1,
#          '本次': 1,
#          '全国性': 1,
#          '限电': 1,
#          '影响': 4,
#          '多大': 1,
#          '应对': 4,
#          '面': 1,
#          '出': 2,
#          '股价': 3,
#          '跌': 1,
#          '芯片': 7,
#          '供应': 2,
#          '激光': 7,
#          '微': 2,
#          '投': 2,
#          '产品': 13,
#          '布局': 2,
#          '如': 1,
#          '没有': 1,
#          '何种': 1,
#          '考量': 1,
#          '投影仪': 4,
#          'vr眼镜': 1,
#          '观看': 3,
#          '3d': 1,
#          '效果': 3,
#          '电影': 1,
#          '玩': 1,
#          '3d游戏': 1,
#          '最新': 2,
#          '股东': 4,
#          '人数': 2,
#          '亚马逊': 1,
#          '封号': 1,
#          '传言': 1,
#          '美国': 1,
#          '一家': 1,
#          '起诉': 1,
#          '专利': 2,
#          '侵权': 1,
#          '员工': 2,
#          '工作时': 1,
#          '长': 1,
#          '招聘': 1,
#          '写': 1,
#          '双休': 1,
#          '实际上': 1,
#          '每个月': 1,
# ...

# %%
seg_list = seg(ret)
ret = ' '.join(seg_list)

# %%
ret=[x.strip() for x in ret if x.strip() != '']

# %%
ret
# Out:
# ['受',
#  '本次',
#  '全国性',
#  '限电',
#  '影响',
#  '多大',
#  '应对',
#  '面出',
#  '股价',
#  '跌',
#  '芯片',
#  '供应',
#  '出',
#  '激光',
#  '微',
#  '投',
#  '产品',
#  '布局',
#  '如没有',
#  '何种',
#  '考量',
#  '投影仪',
#  'vr眼镜',
#  '观看',
#  '3d',
#  '效果',
#  '电影',
#  '玩',
#  '3d游戏',
#  '最新',
#  '股东',
#  '人数',
#  '亚马逊封号',
#  '影响',
#  '传言',
#  '美国',
#  '一家',
#  '起诉',
#  '专利',
#  '侵权',
#  '影响',
#  '员工',
#  '工作时',
#  '长',
#  '招聘',
#  '写',
#  '双休',
#  '实际上',
#  '每个月',
#  '第一个',
#  '周六',
#  '全员',
#  '上班',
#  '加班',
#  '情况',
#  '都是',
#  '晚上',
#  '12点',
#  '下班',
#  '10',
#  '20',
#  '餐补',
#  '段',
#  '时间',
#  '员工',
#  '回家',
#  '身体',
#  '心理',
#  '健康',
#  '保证',
#  '上市',
#  '招股书',
#  '显示',
#  '研发',
#  '费用',
#  '5%',
#  '法定',
#  '社保',
#  '足额',
#  '缴纳',
#  '加班',
#  '薪资',
#  '如实',
#  '发放',
#  '微投',
#  '产品',
#  '有无',
#  '采用',
#  '鸿蒙',
#  '操作系统',
#  '计划',
#  '如有',
#  '华为',
#  '智能',
#  '终端',
#  '合作',
#  '表现形式',
#  '线下',
#  '补课',
#  '趋势',
#  '后期',
#  '都会',
#  '转到',
#  '线上',
#  '补课',
#  '线上',
#  '补课',
#  '话',
#  '手机',
# ...

# %%
# %pylab inline
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (-0.5, 399.5, 199.5, -0.5)

# %%
list(seg_list)

# %%
outstr3
# Out:
# '请   问       董   秘       公   司       受       次       全   国   性       限   电       影   响                   应               面   出               股   价       跌               芯   片       供   应       出                   请   问       贵       公   司       激   光       微       投       产   品       布   局               没       出             考   量               贵       公   司       投   影   仪       v   r   眼   镜       观       d       效   果       电   影       玩       d   游   戏               公   司       新       股   东       数           亚   马   逊   封   号   公   司       影   响           传   言   公   司       美   国       家           公   司       诉       专   利       侵   权       影   响               员   工       工   作   时       长                   招   聘           写       双   休       实   际       月           周   六       全   员       班       公   司       加   班       情   况           晚                 点       班                     餐   补       请   问       段       时   间       员   工       回   家       身   体       心   理       健  
# ...

# %%
data = pd.read_csv('./极米科技投资者问答.csv')
data=data.loc[:, ~data.columns.str.contains('^Unnamed')]
data.head()

# %%
question=data['问题'].apply(lambda x:x.split(':极米科技(688696)')).apply(lambda x:x[1])

# %%
question[1]

# %%
data['提问时间'][0].split(' ')[1]

# %%
data['提问时间']

# %%
data['提问时间'][0]

# %%
data['提问时间'] = data['提问时间'].apply(lambda x:'2021'+''.join(re.split('[月日]', x)))

# %%
data['回答时间'] = data['回答时间'].apply(lambda x:'2021'+''.join(re.split('[月日]', x)))

# %%
data[['提问时间','回答时间']].apply([lambda x:'2021'+''.join(re.split('[月日]', x))])

# %%
data.head()

# %%
ret = pd.to_datetime(data['提问时间'])

# %%
hour=[i.hour for i in ret]
hour

# %%
from collections import Counter

# %%
dict(Counter(hour))

# %%
for key,value in dict(Counter(hour)).items():
    print(key,value)

# %%
ss = data['提问时间'][0]
# ss = ''.join(ss)
ss

# %%
date_list = re.split('[月日]', ss)
d = '2021'+''.join(date_list)
# ''.join(date_list)

# %%
ret1=pd.to_datetime(d)
ret1

# %%
ss2 = data['回答时间'][0]
ss2 = ''.join(ss2)
ss2

# %%
date_list2 = re.split('[月日]', ss2)
d2 = '2021'+''.join(date_list2)
# ''.join(date_list)
ret2=pd.to_datetime(d2)

# %%
 ret2.hour

# %%
(ret2-ret1).days

# %%
import re

ss = '2022年12月12日'

date_list = re.split('[年月日]', ss)[:-1]
date_list_1 = ['0'+d if len(d) == 1 else d for d in date_list]
date_format = '-'.join(date_list_1)
print(date_format)

# %%
date_list = re.split('[月日]',ss)
date_list

# %%
str_list = ' '.join(data['问题'].tolist())

# %%
jieba.enable_paddle()

# %%
seg_list=jieba.cut(''.join(question),use_paddle=True)
list(seg_list)

# %%
words = list(seg_list)

# %%
counts = {}

# %%
for word in words:
  if len(word) == 1:  # 单个词语不计算在内
    continue
  else:
    counts[word] = counts.get(word, 0) + 1

# %%
items = list(counts.items())#将键值对转换成列表
items.sort(key=lambda x: x[1], reverse=True)

# %%
items

# %%
txt_all

# %%
data['来源'].describe()

# %%
Counter(data['来源'])

# %%
(data['时间'].values)[0].split()[0]

# %%
data_date
